# %% [markdown]
# <a href="https://colab.research.google.com/github/ShashwathD/TensorFlowModel/blob/main/SmartGlasses_ObjectReco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tflite-model-maker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 43.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.0/128.0 KB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.6/128.6 KB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 KB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 KB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 71.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 11.1 MB/s eta 0:00:00
# ...

# %%
import os
import tensorflow as tf


from tflite_model_maker import image_classifier
from tflite_model_maker.image_classifier import DataLoader



# Load input data specific to an on-device ML app.
image_path = "/content/person/"    

data = DataLoader.from_folder(image_path)

print(image_path)

train_data, test_data = data.split(0.9)

# Customize the TensorFlow model.
model = image_classifier.create(train_data, batch_size=8)

#  Evaluate the model.
loss, accuracy = model.evaluate(test_data)

# Export to Tensorflow Lite model and label file in `export_dir`.
model.export(export_dir='/tmp/')
# Out:
# /content/person/
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hub_keras_layer_v1v2 (HubKe  (None, 1280)             3413024
#  rasLayerV1V2)
#
#  dropout (Dropout)           (None, 1280)              0
#
#  dense (Dense)               (None, 2)                 2562
#
# ...
# Total params: 3,415,586
# Trainable params: 2,562
# Non-trainable params: 3,413,024
# _________________________________________________________________
# None
# Epoch 1/5
# 1/1 [==============================] - 10s 10s/step - loss: 0.5752 - accuracy: 0.6250
# Epoch 2/5
# 1/1 [==============================] - 4s 4s/step - loss: 0.4875 - accuracy: 0.7500
# Epoch 3/5
# 1/1 [==============================] - 5s 5s/step - loss: 0.2299 - accuracy: 1.0000
# Epoch 4/5
# 1/1 [==============================] - 7s 7s/step - loss: 0.2081 - accuracy: 1.0000
# Epoch 5/5
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !mkdir flowers
# Out:
# mkdir: cannot create directory ‘flowers’: File exists
